# %% [markdown]
# ### 2. 여러가지 플롯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ##### 1. Bar Chart

# %%
y, x = [2, 3, 1], [0,1,2]
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(['가','나','다']), plt.yticks(sorted(y))
plt.xlabel('가나다'), plt.ylabel('빈도수')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\axis.py:1732, in Axis.convert_units(self, x)
#    1731 try:
# -> 1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[2], line 4
#       2 plt.title("Bar Chart")
#       3 plt.bar(x, y)
# ----> 4 plt.xticks(['가','나','다'])
#       5 plt.yticks(sorted(y))
#       6 plt.xlabel('가나다'), plt.ylabel('빈도수')
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\pyplot.py:1886, in xticks(ticks, labels, minor, **kwargs)
#    1883         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    1884                         "without setting 'ticks'")
#    1885 else:
# -> 1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
#    1889     labels = ax.get_xticklabels(minor=minor)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\axis.py:2074, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2071 if labels is None and kwargs:
#    2072     raise ValueError('labels argument cannot be None when '
#    2073                      'kwargs are passed')
# -> 2074 result = self._set_tick_locations(ticks, minor=minor)
#    2075 if labels is not None:
#    2076     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\axis.py:2014, in Axis._set_tick_locations(self, ticks, minor)
#    2010 def _set_tick_locations(self, ticks, *, minor=False):
#    2011     # see docstring of set_ticks
#    2012
#    2013     # XXX if the user changes units, the information will be lost here
# -> 2014     ticks = self.convert_units(ticks)
#    2015     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2016     for name, axis in self.axes._axis_map.items():
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\matplotlib\axis.py:1734, in Axis.convert_units(self, x)
#    1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
# -> 1734     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1735                                  f'units: {x!r}') from e
#    1736 return ret
#
# ConversionError: Failed to convert value(s) to axis units: ['가', '나', '다']

# %%
s = pd.Series(np.random.rand(10), index=list('abcdefghij'))
plt.bar(s.index, s.values)
plt.title('bar chart')
plt.yticks([0,0.2,0.4,0.6,0.8]), plt.xticks([]),plt.grid()
plt.show()

# %%
df = pd.DataFrame(np.random.rand(20).reshape(10,2), 
                 index=list('abcdefghij'), columns=['M','N'])
plt.bar(df.index, df.M.values)
plt.title('bar chart')
plt.show()

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
s = titanic['class'].value_counts()
plt.figure(figsize=(4,2))
plt.barh(s.index, s.values)
plt.title('타이타닉호의 선실별 승객수')
plt.show()

# %% [markdown]
# ##### 2. 파이 차트

# %%
ratio = [10,15,20,25]           # 합이 100이 아니어도 됨
labels = ['감','귤','배','밤']
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.title('파이차트')
plt.show()

# %%
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)
plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors, 
        explode=explode, startangle=90, shadow=True)
plt.title('파이차트')
plt.show()

# %% [markdown]
# ##### 4. 산점도

# %%
np.random.seed(2023)
X, Y = np.random.normal(2,2,100), np.random.randn(100)
plt.figure(figsize=(5,3))
plt.scatter(X,Y)
plt.title('산점도')
plt.show()

# %%
colors=np.random.rand(100)
plt.figure(figsize=(5,3))
plt.scatter(X,Y, c=colors, alpha=0.5)
plt.title('색상을 준 산점도')
plt.show()

# %%
# 점들의 사이즈를 조절
size =500*np.random.rand(100)
plt.figure(figsize=(5,3))
plt.scatter(X,Y, s=size, c=colors, alpha=0.5)
plt.title('버블 차트')
plt.show()

# %% [markdown]
# ##### 5. 이미지 보기

# %%
from PIL import Image
img = Image.open('C:/Users/YONSAI/Pictures/고양이.jpg')

plt.imshow(img);

# %%
plt.imshow(img); plt.axis('off');
