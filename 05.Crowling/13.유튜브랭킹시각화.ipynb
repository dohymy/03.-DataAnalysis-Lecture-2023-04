# %% [markdown]
# ### YouTube Ranking 시각화

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('data/20230428_YouTube랭킹.csv')
df.head(3)
# Out:
#    순위      카테고리          채널명      구독자수          조회수   비디오
# 0   1  음악/댄스/가수    BLACKPINK  87300000  30533500000   507
# 1   2  음악/댄스/가수    BANGTANTV  74500000  20143000000  2188
# 2   3  음악/댄스/가수  HYBE LABELS  70300000  27323160000  1158

# %% [markdown]
# - 구독자수 Top 20을 Barh 차트로 만들기

# %%
plt.figure(figsize=(12,8))
plt.barh(df.채널명.head(20), df.구독자수.head(20))
plt.title('구독자수 top20')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(y='채널명', x='구독자수', data=df.head(20))
plt.title('구독자수 top20')
plt.show()

# %%
df1 = df.head(20).sort_values(by='구독자수')
plt.figure(figsize=(12,7))
plt.barh(df1.채널명.head(20), df1.구독자수.head(20))
plt.title('구독자수 top20')
plt.show()

# %% [markdown]
# - 조회수 top20

# %%
df1 = df.sort_values(by='조회수', ascending=False)

plt.figure(figsize=(12,7))
sns.barplot(y='채널명', x='조회수', data=df1.head(20))
plt.title('조회수 top20')
plt.show()

# %% [markdown]
# - 비디오수 top20

# %%
df2 = df.sort_values(by='비디오', ascending=False)

plt.figure(figsize=(12,7))
sns.barplot(y='채널명', x='비디오', data=df2.head(20))
plt.title('비디오 top20')
plt.show()

# %% [markdown]
# - 카테고리별 채널수

# %%
df3 = df.카테고리.value_counts().to_frame()
df3
# Out:
#            count
# 카테고리
# 음악/댄스/가수      38
# 키즈/어린이        24
# 음식/요리/레시피     12
# TV/방송         11
# 미분류            5
# 뉴스/정치/사회       3
# 회사/오피셜         2
# BJ/인물/연예인      2
# 해외             1
# 패션/미용          1
# 애완/반려동물        1

# %%
df.pivot_table('채널명', '카테고리', aggfunc='count').sort_values('채널명', ascending=False)
# Out:
#            채널명
# 카테고리
# 음악/댄스/가수    38
# 키즈/어린이      24
# 음식/요리/레시피   12
# TV/방송       11
# 미분류          5
# 뉴스/정치/사회     3
# BJ/인물/연예인    2
# 회사/오피셜       2
# 애완/반려동물      1
# 패션/미용        1
# 해외           1

# %%
sns.barplot(y=df3.index, x='count', data=df3);

# %% [markdown]
# - 카테고리별 구독자수 top10

# %%
df4 = df.pivot_table('구독자수', '카테고리', aggfunc='sum').sort_values('구독자수', ascending=False)
df4.head(10)
# Out:
#                 구독자수
# 카테고리
# 음악/댄스/가수   618700000
# 키즈/어린이     211970000
# 음식/요리/레시피  104950000
# TV/방송       88380000
# 미분류         34730000
# 뉴스/정치/사회    21830000
# 회사/오피셜      13120000
# BJ/인물/연예인   10760000
# 해외           8760000
# 패션/미용        5950000

# %%
sns.barplot(y=df4.index[:10], x=df4.구독자수.head(10))
# Out:
# <Axes: xlabel='구독자수', ylabel='카테고리'>
